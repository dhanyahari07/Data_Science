# %% [markdown]
# # DATA

# %% [markdown]
# ![alt text](https://www.geeksforgeeks.org/wp-content/uploads/creating_dataframe1.png)

# %% [markdown]
# ## Manually Create a DataFrame

# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df = pd.DataFrame(weather_data)

df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# ## CSV File from Goole Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Reading CSV File

# %%
df = pd.read_csv("/content/drive/My Drive/pandas/weather_data.csv")

#'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'

# df = pd.read_csv('url of your data')

# pd.read_csv('pandas_tutorial_read.csv', delimiter=';')

# pd.read_csv('pandas_tutorial_read.csv', delimiter=';', names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])

# %% [markdown]
# ## Display First Few rows

# %%
df.head(3) # df.head(10)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## Display last few rows

# %%
df.tail(3) # df.tail(3)
# Out:
#         day  temperature  windspeed  event
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# ## Random Selection of rows

# %%
df.sample(3)
# Out:
#         day  temperature  windspeed event
# 3  1/4/2017           24          7  Snow
# 2  1/3/2017           28          2  Snow
# 4  1/5/2017           32          4  Rain

# %% [markdown]
# ## Count number of rows and columns/dataset size

# %%
df.shape 
rows, columns = df.shape
columns
# Out:
# 4

# %% [markdown]
# ## Display the column titles

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %% [markdown]
# ## The data type of all coumns

# %%
df.dtypes
# Out:
# day            object
# temperature     int64
# windspeed       int64
# event          object
# dtype: object

# %% [markdown]
# ## Change the default index of a dataframe

# %%
df.set_index('day')
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %% [markdown]
# ## Observe the original DataFrame!!!! NOT CHANGED

# %%
df # NOT CHANGED
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# ## inplace parameter

# %%
df.set_index('day', inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %% [markdown]
# ## reset the index back

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# ## Select a specific column

# %%
df['temperature']
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: temperature, dtype: int64

# %%
df['temperature']=df['temperature']+1

# %%
df['temperature']
# Out:
# 0    33
# 1    36
# 2    29
# 3    25
# 4    33
# 5    32
# Name: temperature, dtype: int64

# %% [markdown]
# ## Select Multiple columns

# %%
df[['temperature','event']]
# Out:
#    temperature  event
# 0           33   Rain
# 1           36  Sunny
# 2           29   Snow
# 3           25   Snow
# 4           33   Rain
# 5           32  Sunny

# %%
df.event
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %% [markdown]
# ## Total info about DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %% [markdown]
# ## Change Column name

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.rename(columns={
        'event': 'Event', 
        'temperature': 'TEMPERATURE'
    }, inplace=True)


df.columns
# Out:
# Index(['day', 'TEMPERATURE', 'windspeed', 'Event'], dtype='object')

# %%
df.head()
# Out:
#         day  TEMPERATURE  windspeed  Event
# 0  1/1/2017           33          6   Rain
# 1  1/2/2017           36          7  Sunny
# 2  1/3/2017           29          2   Snow
# 3  1/4/2017           25          7   Snow
# 4  1/5/2017           33          4   Rain

# %% [markdown]
# ## Statistics of DataFrame

# %%
df.describe()
# Out:
#        TEMPERATURE  windspeed
# count     6.000000   6.000000
# mean     31.333333   4.666667
# std       3.829708   2.338090
# min      25.000000   2.000000
# 25%      29.750000   2.500000
# 50%      32.500000   5.000000
# 75%      33.000000   6.750000
# max      36.000000   7.000000

# %%
df.describe(include='all')
# Out:
#              day  TEMPERATURE  windspeed Event
# count          6     6.000000   6.000000     6
# unique         6          NaN        NaN     3
# top     1/4/2017          NaN        NaN  Snow
# freq           1          NaN        NaN     2
# mean         NaN    31.333333   4.666667   NaN
# std          NaN     3.829708   2.338090   NaN
# min          NaN    25.000000   2.000000   NaN
# 25%          NaN    29.750000   2.500000   NaN
# 50%          NaN    32.500000   5.000000   NaN
# 75%          NaN    33.000000   6.750000   NaN
# max          NaN    36.000000   7.000000   NaN

# %% [markdown]
# ## Count of categories

# %%
df['Event'].value_counts()
# Out:
# Snow     2
# Rain     2
# Sunny    2
# Name: Event, dtype: int64

# %%
df['windspeed'].value_counts()
# Out:
# 7    2
# 2    2
# 6    1
# 4    1
# Name: windspeed, dtype: int64

# %% [markdown]
# ## Delete a specific column

# %%
df.drop(['Event'], axis = 1)
# Out:
#         day  TEMPERATURE  windspeed
# 0  1/1/2017           33          6
# 1  1/2/2017           36          7
# 2  1/3/2017           29          2
# 3  1/4/2017           25          7
# 4  1/5/2017           33          4
# 5  1/6/2017           32          2

# %%
df
# Out:
#         day  TEMPERATURE  windspeed  Event
# 0  1/1/2017           33          6   Rain
# 1  1/2/2017           36          7  Sunny
# 2  1/3/2017           29          2   Snow
# 3  1/4/2017           25          7   Snow
# 4  1/5/2017           33          4   Rain
# 5  1/6/2017           32          2  Sunny

# %%
df.drop(['Event'], axis = 1,inplace=True)

# %%
df
# Out:
#         day  TEMPERATURE  windspeed
# 0  1/1/2017           33          6
# 1  1/2/2017           36          7
# 2  1/3/2017           29          2
# 3  1/4/2017           25          7
# 4  1/5/2017           33          4
# 5  1/6/2017           32          2

# %%
# df.drop(['C', 'D'], axis = 1) 
  
# df.drop(columns =['C', 'D']) 

# df.drop(df.columns[[0, 4, 2]], axis = 1, inplace = True)

# %% [markdown]
# TRY these commands for the following dataset
# https://raw.githubusercontent.com/pplonski/datasets-for-start/master/credit/data.csv

# %% [markdown]
# # QUIZ

# %% [markdown]
# https://forms.office.com/Pages/ResponsePage.aspx?id=o835AF4H5USqC6ujrdZTn63NXi4eP7xHpYuejR_M4qdUNEYzVVRTRlhMMFlIODRDUTBLM1VCWjRNSi4u

# %% [markdown]
# [link text](https://forms.office.com/Pages/ResponsePage.aspx?id=o835AF4H5USqC6ujrdZTn63NXi4eP7xHpYuejR_M4qdUNEYzVVRTRlhMMFlIODRDUTBLM1VCWjRNSi4u)
