# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd

airports = pd.read_csv('/content/drive/My Drive/pandas/airports.csv')
airport_freq = pd.read_csv('/content/drive/My Drive/pandas/airport-frequencies.csv')
runways = pd.read_csv('/content/drive/My Drive/pandas/runways.csv')

# %% [markdown]
# ## select * from airports

# %%
airports
# Out:
#            id  ...              keywords
# 0        6523  ...                   NaN
# 1      323361  ...                   NaN
# 2        6524  ...                   NaN
# 3        6525  ...                   NaN
# 4        6526  ...                  00AR
# ...       ...  ...                   ...
# 56201  317861  ...                   NaN
# 56202   32753  ...                   NaN
# 56203   46378  ...  Roughs Tower Helipad
# 56204  307326  ...                   NaN
# 56205  313629  ...  SATSUMA,IWOJIMA,RJX7
#
# [56206 rows x 18 columns]

# %% [markdown]
# ## select * from airports limit 3

# %%
airports.head(3)
# Out:
#        id ident           type  ... home_link  wikipedia_link  keywords
# 0    6523   00A       heliport  ...       NaN             NaN       NaN
# 1  323361  00AA  small_airport  ...       NaN             NaN       NaN
# 2    6524  00AK  small_airport  ...       NaN             NaN       NaN
#
# [3 rows x 18 columns]

# %% [markdown]
# ## select id from airports where ident = 'KLAX'

# %%
airports[airports.ident == 'KLAX'].id
# Out:
# 28445    3632
# Name: id, dtype: int64

# %% [markdown]
# ## select distinct type from airport

# %%
airports.type.unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %% [markdown]
# # SELECT with multiple conditions

# %% [markdown]
# ## select * from airports where iso_region = 'US-CA' and type = 'seaplane_base'

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'seaplane_base')]
# Out:
#            id ident           type  ... home_link  wikipedia_link  keywords
# 980      7436   0O0  seaplane_base  ...       NaN             NaN       NaN
# 2499     8877  22CA  seaplane_base  ...       NaN             NaN       NaN
# 6266    12298  5CA9  seaplane_base  ...       NaN             NaN       NaN
# 13206   16514   C39  seaplane_base  ...       NaN             NaN       NaN
# 15546   16830  CN20  seaplane_base  ...       NaN             NaN       NaN
# 17932   17157   E20  seaplane_base  ...       NaN             NaN       NaN
# 23406   17613   H77  seaplane_base  ...       NaN             NaN       NaN
# 31182   21444   L11  seaplane_base  ...       NaN             NaN       NaN
# 37933   23479   O06  seaplane_base  ...       NaN             NaN       NaN
# 41625   24384   S74  seaplane_base  ...       NaN             NaN       NaN
# 49098  300312   TWH  seaplane_base  ...       NaN             NaN       NaN
#
# [11 rows x 18 columns]

# %% [markdown]
# ## select ident, name, municipality from airports where iso_region = 'US-CA' and type = 'large_airport'

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'large_airport')][['ident', 'name', 'municipality']]
# Out:
#       ident                                             name   municipality
# 26817  KBAB                             Beale Air Force Base     Marysville
# 27655  KEDW                           Edwards Air Force Base        Edwards
# 28445  KLAX                Los Angeles International Airport    Los Angeles
# 28972  KOAK       Metropolitan Oakland International Airport        Oakland
# 29028  KONT                    Ontario International Airport        Ontario
# 30549  KSAN                  San Diego International Airport      San Diego
# 30589  KSFO              San Francisco International Airport  San Francisco
# 30610  KSJC  Norman Y. Mineta San Jose International Airport       San Jose
# 30632  KSMF                 Sacramento International Airport     Sacramento
# 30638  KSNA         John Wayne Airport-Orange County Airport      Santa Ana
# 30687  KSUU                            Travis Air Force Base      Fairfield
# 30920  KVBG                        Vandenberg Air Force Base         Lompoc

# %% [markdown]
# # ORDER BY

# %% [markdown]
# ## select * from airport_freq where airport_ident = 'KLAX' order by type

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type')
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11940  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11941  60766         3632          KLAX   APP   SOCAL APP         124.30
# 11942  60768         3632          KLAX  ATIS        ATIS         133.80
# 11943  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11944  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11945  60771         3632          KLAX   GND         GND         121.65
# 11946  60772         3632          KLAX  MISC          CG          34.50
# 11947  60773         3632          KLAX  MISC          CG         898.40
# 11948  60774         3632          KLAX   OPS          AF          37.22
# 11949  60775         3632          KLAX   TWR         TWR         119.80
# 11950  60776         3632          KLAX  UNIC      UNICOM         122.95

# %% [markdown]
# ## select * from airport_freq where airport_ident = 'KLAX' order by type desc

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type', ascending=False)
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11950  60776         3632          KLAX  UNIC      UNICOM         122.95
# 11949  60775         3632          KLAX   TWR         TWR         119.80
# 11948  60774         3632          KLAX   OPS          AF          37.22
# 11946  60772         3632          KLAX  MISC          CG          34.50
# 11947  60773         3632          KLAX  MISC          CG         898.40
# 11945  60771         3632          KLAX   GND         GND         121.65
# 11944  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11943  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11942  60768         3632          KLAX  ATIS        ATIS         133.80
# 11940  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11941  60766         3632          KLAX   APP   SOCAL APP         124.30

# %% [markdown]
# # IN… NOT IN

# %% [markdown]
# ## select * from airports where type in ('heliport', 'balloonport')

# %%
airports[airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id  ...              keywords
# 0        6523  ...                   NaN
# 9      322658  ...                   NaN
# 12       6532  ...                   NaN
# 15       6535  ...                   NaN
# 16       6536  ...                   NaN
# ...       ...  ...                   ...
# 55820  312611  ...                   NaN
# 55822  312624  ...                   NaN
# 55843  318475  ...                   NaN
# 55941  301278  ...                   NaN
# 56203   46378  ...  Roughs Tower Helipad
#
# [11516 rows x 18 columns]

# %% [markdown]
# ## select * from airports where type not in ('heliport', 'balloonport')

# %%
airports[~airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id  ...              keywords
# 1      323361  ...                   NaN
# 2        6524  ...                   NaN
# 3        6525  ...                   NaN
# 4        6526  ...                  00AR
# 5      322127  ...                   NaN
# ...       ...  ...                   ...
# 56200   27244  ...                   NaN
# 56201  317861  ...                   NaN
# 56202   32753  ...                   NaN
# 56204  307326  ...                   NaN
# 56205  313629  ...  SATSUMA,IWOJIMA,RJX7
#
# [44690 rows x 18 columns]

# %% [markdown]
# # GROUP BY, COUNT, ORDER BY

# %% [markdown]
# ## select iso_country, type, count(*) from airports group by iso_country, type order by iso_country, type

# %%
airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           heliport            2
# AE           closed              1
#              heliport           21
#              large_airport       4
#              medium_airport      7
#                               ...
# ZM           small_airport      94
# ZW           closed              2
#              large_airport       1
#              medium_airport      8
#              small_airport     128
# Length: 846, dtype: int64

# %% [markdown]
# ## select iso_country, type, count(*) from airports group by iso_country, type order by iso_country, count(*) desc

# %%
airports.groupby(['iso_country', 'type']).size().to_frame('size').reset_index().sort_values(['iso_country', 'size'], ascending=[True, False])
# Out:
#     iso_country            type  size
# 0            AD        heliport     2
# 2            AE        heliport    21
# 6            AE   small_airport    15
# 4            AE  medium_airport     7
# 3            AE   large_airport     4
# ..          ...             ...   ...
# 839          ZM   large_airport     1
# 845          ZW   small_airport   128
# 844          ZW  medium_airport     8
# 842          ZW          closed     2
# 843          ZW   large_airport     1
#
# [846 rows x 3 columns]

# %% [markdown]
# ## select iso_country, type, count(*) from airports group by iso_country, type order by iso_country, type

# %%
airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           heliport            2
# AE           closed              1
#              heliport           21
#              large_airport       4
#              medium_airport      7
#                               ...
# ZM           small_airport      94
# ZW           closed              2
#              large_airport       1
#              medium_airport      8
#              small_airport     128
# Length: 846, dtype: int64

# %% [markdown]
# ## select iso_country, type, count(*) from airports group by iso_country, type order by iso_country, count(*) desc

# %%
airports.groupby(['iso_country', 'type']).size().to_frame('size').reset_index().sort_values(['iso_country', 'size'], ascending=[True, False])
# Out:
#     iso_country            type  size
# 0            AD        heliport     2
# 2            AE        heliport    21
# 6            AE   small_airport    15
# 4            AE  medium_airport     7
# 3            AE   large_airport     4
# ..          ...             ...   ...
# 839          ZM   large_airport     1
# 845          ZW   small_airport   128
# 844          ZW  medium_airport     8
# 842          ZW          closed     2
# 843          ZW   large_airport     1
#
# [846 rows x 3 columns]

# %% [markdown]
# # HAVING

# %% [markdown]
# ## select type, count(*) from airports where iso_country = 'US' group by type having count(*) > 1000 order by count(*) desc

# %%
airports[airports.iso_country == 'US'].groupby('type').filter(lambda g: len(g) > 1000).groupby('type').size().sort_values(ascending=False)
# Out:
# type
# small_airport    13544
# heliport          6233
# closed            1737
# dtype: int64

# %% [markdown]
# In the next example, we order things by airport_count and only select the top 10 countries with the largest count. Second example is the more complicated case, in which we want “the next 10 after the top 10”:

# %% [markdown]
# ## select iso_country from by_country order by size desc limit 10

# %%
airport_freq.head(3)
# Out:
#        id  airport_ref airport_ident   type          description  frequency_mhz
# 0   70518         6528          00CA   CTAF                 CTAF          122.9
# 1  307581         6589          01FL  ARCAL                  NaN          122.9
# 2   75239         6589          01FL   CTAF  CEDAR KNOLL TRAFFIC          122.8

# %%
airports.head(3)
# Out:
#        id ident           type  ... home_link  wikipedia_link  keywords
# 0    6523   00A       heliport  ...       NaN             NaN       NaN
# 1  323361  00AA  small_airport  ...       NaN             NaN       NaN
# 2    6524  00AK  small_airport  ...       NaN             NaN       NaN
#
# [3 rows x 18 columns]

# %%
by_country=airports.groupby(['iso_country']).size().to_frame('airport_count').reset_index().sort_values(['iso_country', 'airport_count'], ascending=[True, False])

# %%
by_country.head()
# Out:
#   iso_country  airport_count
# 0          AD              2
# 1          AE             52
# 2          AF             65
# 3          AG              3
# 4          AI              1

# %%
by_country.nlargest(10, columns='airport_count')
# Out:
#     iso_country  airport_count
# 224          US          22956
# 29           BR           4618
# 35           CA           2793
# 12           AU           1966
# 117          KR           1374
# 152          MX           1355
# 74           GB           1154
# 184          RU           1072
# 54           DE            954
# 72           FR            891

# %% [markdown]
# ## select iso_country from by_country order by size desc limit 10 offset 10

# %%
by_country.nlargest(20, columns='airport_count').tail(10)
# Out:
#     iso_country  airport_count
# 9            AR            861
# 46           CO            706
# 105          IT            689
# 170          PG            595
# 229          VE            592
# 239          ZA            493
# 43           CL            480
# 96           ID            478
# 65           ES            444
# 45           CN            411

# %% [markdown]
# # Aggregate functions (MIN, MAX, MEAN)

# %% [markdown]
# ## Calculate min, max, mean, and median length of a runway:
# ## select max(length_ft), min(length_ft), avg(length_ft), median(length_ft) from runways

# %%
runways.agg({'length_ft': ['min', 'max', 'mean', 'median']})
# Out:
#             length_ft
# min          0.000000
# max     120000.000000
# mean      3262.116384
# median    2744.000000

# %% [markdown]
# # JOIN

# %% [markdown]
# Use .merge() to join Pandas dataframes. You need to provide which columns to join on (left_on and right_on), and join type: inner (default), left (corresponds to LEFT OUTER in SQL), right (RIGHT OUTER), or outer (FULL OUTER).

# %% [markdown]
# ## select airport_ident, type, description, frequency_mhz from airport_freq join airports on airport_freq.airport_ref = airports.id where airports.ident = 'KLAX'

# %%
airport_freq.merge(airports[airports.ident == 'KLAX'][['id']], left_on='airport_ref', right_on='id', how='inner')[['airport_ident', 'type', 'description', 'frequency_mhz']]
# Out:
#    airport_ident  type description  frequency_mhz
# 0           KLAX   APP   SOCAL APP          36.07
# 1           KLAX   APP   SOCAL APP         124.30
# 2           KLAX  ATIS        ATIS         133.80
# 3           KLAX   CLD    CLNC DEL         121.40
# 4           KLAX   DEP   SOCAL DEP         124.30
# 5           KLAX   GND         GND         121.65
# 6           KLAX  MISC          CG          34.50
# 7           KLAX  MISC          CG         898.40
# 8           KLAX   OPS          AF          37.22
# 9           KLAX   TWR         TWR         119.80
# 10          KLAX  UNIC      UNICOM         122.95

# %% [markdown]
# # UNION ALL and UNION

# %% [markdown]
# ## select name, municipality from airports where ident = 'KLAX' union all select name, municipality from airports where ident = 'KLGB'

# %%
pd.concat([airports[airports.ident == 'KLAX'][['name', 'municipality']], airports[airports.ident == 'KLGB'][['name', 'municipality']]])
# Out:
#                                        name municipality
# 28445     Los Angeles International Airport  Los Angeles
# 28470  Long Beach /Daugherty Field/ Airport   Long Beach

# %% [markdown]
# # INSERT

# %% [markdown]
# ## create table heroes (id integer, name text);

# %%
df1 = pd.DataFrame({'id': [1, 2], 'name': ['Harry Potter', 'Ron Weasley']})

# %% [markdown]
# ## insert into heroes values (1, 'Harry Potter');

# %%
df2 = pd.DataFrame({'id': [3], 'name': ['Hermione Granger']})

# %% [markdown]
# # UPDATE

# %% [markdown]
# ## update airports set home_link = 'http://www.lawa.org/welcomelax.aspx' where ident == 'KLAX'

# %%
airports.loc[airports['ident'] == 'KLAX', 'home_link'] = 'http://www.lawa.org/welcomelax.aspx'

# %% [markdown]
# # DELETE

# %% [markdown]
# ## delete from lax_freq where type = 'MISC'

# %%
lax_freq = lax_freq[lax_freq.type != 'MISC']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-2f374ea2b4c6> in <module>()
# ----> 1 lax_freq = lax_freq[lax_freq.type != 'MISC']
#
# NameError: name 'lax_freq' is not defined

# %%
https://medium.com/jbennetcodes/how-to-rewrite-your-sql-queries-in-pandas-and-more-149d341fc53e
