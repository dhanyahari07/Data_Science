# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/My Drive/Data Science/big_mart.csv')

# %%
df=df.dropna(how='any')

# %%
df=df.reset_index(drop=True)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0           FDA15        9.300  ...  Supermarket Type1          3735.1380
# 1           DRC01        5.920  ...  Supermarket Type2           443.4228
# 2           FDN15       17.500  ...  Supermarket Type1          2097.2700
# 3           NCD19        8.930  ...  Supermarket Type1           994.7052
# 4           FDP36       10.395  ...  Supermarket Type2           556.6088
#
# [5 rows x 12 columns]

# %%
price_by_item=df.groupby('Item_Type')

# %%
price_by_item.first() # display few rows
# Out:
#                       Item_Identifier  ...  Item_Outlet_Sales
# Item_Type                              ...
# Baking Goods                    FDP36  ...           556.6088
# Breads                          FDW11  ...           619.1940
# Breakfast                       FDP49  ...          1547.3192
# Canned                          FDC02  ...          6768.5228
# Dairy                           FDA15  ...          3735.1380
# Frozen Foods                    FDR28  ...          4078.0250
# Fruits and Vegetables           FDY07  ...          1516.0266
# Hard Drinks                     DRJ59  ...           308.9312
# Health and Hygiene              NCB42  ...          1621.8888
# Household                       NCD19  ...           994.7052
# Meat                            FDN15  ...          2097.2700
# Others                          NCM43  ...          2120.5730
# Seafood                         FDH21  ...          1267.6832
# ...

# %%
price_by_item.Item_MRP.mean()
# Out:
# Item_Type
# Baking Goods             125.795653
# Breads                   141.300639
# Breakfast                134.090683
# Canned                   138.551179
# Dairy                    149.481471
# Frozen Foods             140.095830
# Fruits and Vegetables    145.418257
# Hard Drinks              140.102908
# Health and Hygiene       131.437324
# Household                149.884244
# Meat                     140.279344
# Others                   137.640870
# Seafood                  146.595782
# Snack Foods              147.569955
# Soft Drinks              130.910182
# Starchy Foods            151.256747
# Name: Item_MRP, dtype: float64

# %%
multiple_groups=df[:10].groupby(['Item_Type','Item_Fat_Content'])

# %%
multiple_groups.first()
# Out:
#                                        Item_Identifier  ...  Item_Outlet_Sales
# Item_Type             Item_Fat_Content                  ...
# Baking Goods          Regular                    FDP36  ...           556.6088
# Dairy                 Low Fat                    FDA15  ...          3735.1380
#                       Regular                    FDA03  ...          2187.1530
# Fruits and Vegetables Low Fat                    FDY07  ...          1516.0266
#                       Regular                    FDX32  ...          1589.2646
# Household             Low Fat                    NCD19  ...           994.7052
# Meat                  Low Fat                    FDN15  ...          2097.2700
# Snack Foods           Regular                    FDO10  ...           343.5528
# Soft Drinks           Regular                    DRC01  ...           443.4228
#
# [9 rows x 10 columns]

# %%
# outlit size based on city type

# %%
pd.crosstab(df['Outlet_Size'],df['Outlet_Location_Type'],margins=True)
# Out:
# Outlet_Location_Type  Tier 1  Tier 2  Tier 3   All
# Outlet_Size
# High                       0       0     932   932
# Medium                   930       0     928  1858
# Small                    930     930       0  1860
# All                     1860     930    1860  4650

# %%
# how sales changing per year

# %%
pd.pivot_table(df,index=['Outlet_Establishment_Year'],values="Item_Outlet_Sales")
# Out:
#                            Item_Outlet_Sales
# Outlet_Establishment_Year
# 1987                             2298.995256
# 1997                             2277.844267
# 1999                             2348.354635
# 2004                             2438.841866
# 2009                             1995.498739

# %%
pd.pivot_table(df,index=['Outlet_Establishment_Year','Outlet_Location_Type','Outlet_Size'],values="Item_Outlet_Sales")
# Out:
#                                                             Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Location_Type Outlet_Size
# 1987                      Tier 3               High               2298.995256
# 1997                      Tier 1               Small              2277.844267
# 1999                      Tier 1               Medium             2348.354635
# 2004                      Tier 2               Small              2438.841866
# 2009                      Tier 3               Medium             1995.498739

# %%
pd.pivot_table(df,index=['Outlet_Establishment_Year','Outlet_Location_Type','Outlet_Size'],values="Item_Outlet_Sales",aggfunc=[np.mean,np.median,min,max])
# Out:
#                                                                         mean  ...               max
#                                                            Item_Outlet_Sales  ... Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Location_Type Outlet_Size                    ...
# 1987                      Tier 3               High              2298.995256  ...        10256.6490
# 1997                      Tier 1               Small             2277.844267  ...         9779.9362
# 1999                      Tier 1               Medium            2348.354635  ...         7646.0472
# 2004                      Tier 2               Small             2438.841866  ...         8479.6288
# 2009                      Tier 3               Medium            1995.498739  ...         6768.5228
#
# [5 rows x 4 columns]
