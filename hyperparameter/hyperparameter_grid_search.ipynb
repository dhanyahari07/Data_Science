# %%
# Importing the necessary packages
import pandas as pd
import numpy as np
import keras
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip 'drive/My Drive/DeepLearning/pima-indians-diabetes-database.zip'
# Out:
# Archive:  drive/My Drive/DeepLearning/pima-indians-diabetes-database.zip
#   inflating: diabetes.csv

# %%
# Reading the file
df = pd.read_csv('/content/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
df.shape # Shape of ‘df’
# Out:
# (768, 9)

# %%
df.columns # Prints columns of ‘df’
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.describe() # Displays properties of each column
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
dataset = df.values

# %%
X = dataset[:,0:8]
y = dataset[:,8].astype('int')

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Standardization
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1  ...             6             7
# count  7.680000e+02  7.680000e+02  ...  7.680000e+02  7.680000e+02
# mean   2.544261e-17  3.614007e-18  ...  2.398978e-16  1.857600e-16
# std    1.000652e+00  1.000652e+00  ...  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00  ... -1.189553e+00 -1.041549e+00
# 25%   -8.448851e-01 -6.852363e-01  ... -6.889685e-01 -7.862862e-01
# 50%   -2.509521e-01 -1.218877e-01  ... -3.001282e-01 -3.608474e-01
# 75%    6.399473e-01  6.057709e-01  ...  4.662269e-01  6.602056e-01
# max    3.906578e+00  2.444478e+00  ...  5.883565e+00  4.063716e+00
#
# [8 rows x 8 columns]

# %% [markdown]
# # Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam

# %%
def create_model():
  model=Sequential()
  model.add(Dense(8,input_dim=8,kernel_initializer='normal',activation='relu'))
  model.add(Dense(4,kernel_initializer='normal',activation='relu'))
  model.add(Dense(1,activation='sigmoid'))
  adam=Adam(lr=0.01)
  model.compile(loss='binary_crossentropy',optimizer=adam,metrics=['accuracy'])
  return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)

# %%
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]

# %%
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)

# %%
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............ batch_size=10, epochs=10, score=0.740, total=   1.3s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.708, total=   1.3s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.6s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.773, total=   1.3s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.9s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.869, total=   1.3s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    5.1s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.765, total=   1.3s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    6.4s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.753, total=   3.6s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    9.9s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.701, total=   3.6s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   13.6s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.773, total=   3.7s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   17.2s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.797, total=   3.6s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   20.9s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.732, total=   3.7s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.734, total=   6.6s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.708, total=   6.5s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.747, total=   6.5s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.771, total=   6.5s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.765, total=   6.5s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.727, total=   1.0s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.727, total=   1.0s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.760, total=   1.0s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.850, total=   1.0s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.765, total=   1.6s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.753, total=   2.2s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.708, total=   2.2s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.727, total=   2.2s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.837, total=   2.2s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.752, total=   2.2s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.753, total=   3.7s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.740, total=   3.9s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.766, total=   3.8s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.791, total=   3.8s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.810, total=   3.8s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.727, total=   0.9s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.714, total=   0.9s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.773, total=   0.9s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.797, total=   0.9s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.765, total=   0.9s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.714, total=   1.6s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.734, total=   1.6s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.766, total=   1.5s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.771, total=   1.5s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.784, total=   1.5s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.753, total=   2.3s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.714, total=   3.0s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.766, total=   2.3s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.778, total=   2.3s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.778, total=   2.3s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  2.0min finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7722094893455506, using {'batch_size': 20, 'epochs': 100}
# 0.7709532380104065,0.05411457987647595 with: {'batch_size': 10, 'epochs': 10}
# 0.7513368964195252,0.0330405966550607 with: {'batch_size': 10, 'epochs': 50}
# 0.7448518991470336,0.022761971308679428 with: {'batch_size': 10, 'epochs': 100}
# 0.7657329678535462,0.04481363438595666 with: {'batch_size': 20, 'epochs': 10}
# 0.7553094029426575,0.04397743716958056 with: {'batch_size': 20, 'epochs': 50}
# 0.7722094893455506,0.025402559466024124 with: {'batch_size': 20, 'epochs': 100}
# 0.7552754521369934,0.030433778912752563 with: {'batch_size': 40, 'epochs': 10}
# 0.7539682626724243,0.02589397915188647 with: {'batch_size': 40, 'epochs': 50}
# 0.7578643560409546,0.02359472595269526 with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# # Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 20,epochs = 100)

# %%
# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# %%
# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# %%
# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.753, total=   3.8s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.8s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.721, total=   3.9s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    7.7s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.773, total=   4.0s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   11.8s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.850, total=   4.0s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   15.8s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.765, total=   3.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   19.6s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.727, total=   3.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   23.4s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.708, total=   3.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   27.2s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.766, total=   3.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   31.0s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.784, total=   3.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   34.8s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.745, total=   3.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.701, total=   3.7s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.649, total=   3.7s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.766, total=   3.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.771, total=   3.7s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.745, total=   3.7s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.753, total=   4.2s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.721, total=   4.9s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.766, total=   4.4s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.837, total=   4.4s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.752, total=   4.3s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.740, total=   4.3s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.662, total=   4.3s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.630, total=   4.4s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.771, total=   4.2s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.745, total=   4.3s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.714, total=   4.4s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.695, total=   4.2s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.714, total=   4.3s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.719, total=   4.1s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.725, total=   4.1s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.747, total=   4.1s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.708, total=   4.2s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.753, total=   4.2s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.830, total=   4.2s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.765, total=   4.1s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.747, total=   4.2s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.682, total=   5.0s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.766, total=   4.3s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.824, total=   4.3s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.758, total=   4.3s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.682, total=   4.4s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.695, total=   4.2s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.675, total=   4.2s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.719, total=   4.3s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.745, total=   4.2s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  3.1min finished

# %%
# Summarize the results

print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7722264647483825, using {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7722264647483825,0.042571952706404334 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7461421012878418,0.027161014732286305 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7266445994377136,0.045855237488878126 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.7656990051269531,0.0384658099110809 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.7097614884376526,0.054019075617181514 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7135642290115356,0.010239371933163936 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.7605126976966858,0.03969060759660273 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.7553009152412414,0.04528942635150578 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.7032000780105591,0.025722876542502087 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# # Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.0))
    model.add(Dense(4,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.0))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)

# %%
# Define the grid search parameters

activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# %%
# Make a dictionary of the grid search parameters

param_grids = dict(activation_function = activation_function,init = init)

# %%
# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  activation_function=softmax, init=uniform, score=0.747, total=   2.5s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.740, total=   2.5s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.766, total=   2.4s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.3s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.850, total=   2.4s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    9.7s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.752, total=   2.4s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   12.2s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.747, total=   2.6s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   14.7s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.727, total=   2.5s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   17.3s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.766, total=   2.4s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   19.7s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.837, total=   2.3s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   22.0s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.758, total=   2.4s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.649, total=   2.4s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.584, total=   3.1s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.630, total=   2.4s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.745, total=   2.4s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.647, total=   2.4s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.747, total=   2.4s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.695, total=   2.4s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.747, total=   2.4s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.830, total=   2.4s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.752, total=   2.4s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.760, total=   2.4s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.727, total=   2.4s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.766, total=   2.4s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.830, total=   2.4s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.784, total=   2.4s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.649, total=   2.4s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.584, total=   2.3s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.630, total=   2.3s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.745, total=   2.4s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.647, total=   2.6s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.760, total=   2.5s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.734, total=   3.3s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.760, total=   2.5s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.843, total=   2.4s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.752, total=   2.4s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.766, total=   2.3s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.734, total=   2.4s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.766, total=   2.4s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.843, total=   2.4s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.745, total=   2.4s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.649, total=   2.4s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.584, total=   2.4s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.630, total=   2.4s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.745, total=   2.5s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.647, total=   2.5s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.773, total=   2.4s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.727, total=   2.5s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.760, total=   2.5s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.830, total=   2.3s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.765, total=   2.4s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.773, total=   2.9s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.727, total=   3.3s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.766, total=   4.2s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.824, total=   2.4s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.765, total=   2.5s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.649, total=   2.5s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.584, total=   2.4s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.630, total=   2.4s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.745, total=   2.4s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.647, total=   2.4s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  2.5min finished

# %%
# Summarize the results

print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7735251665115357, using {'activation_function': 'relu', 'init': 'normal'}
# 0.7709107995033264,0.040299030119075194 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 0.7670062065124512,0.03717817749635853 with: {'activation_function': 'softmax', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'zero'}
# 0.7540022253990173,0.043360332521885814 with: {'activation_function': 'relu', 'init': 'uniform'}
# 0.7735251665115357,0.03375103917510477 with: {'activation_function': 'relu', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.7696035981178284,0.03797102405611401 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.7708938121795654,0.03822675839501876 with: {'activation_function': 'tanh', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'tanh', 'init': 'zero'}
# 0.7709022998809815,0.033377010425694416 with: {'activation_function': 'linear', 'init': 'uniform'}
# 0.7708938121795654,0.03077880004304721 with: {'activation_function': 'linear', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# # Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# %%
# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# %%
# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# %%
# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................ neuron1=4, neuron2=2, score=0.649, total=   1.1s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.708, total=   1.2s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.3s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.760, total=   1.1s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.4s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.804, total=   1.1s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    4.6s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.647, total=   1.1s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.7s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.649, total=   1.1s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    6.8s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.643, total=   1.1s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    8.0s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.630, total=   1.2s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    9.1s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.745, total=   1.1s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   10.3s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.758, total=   1.1s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.740, total=   1.1s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.584, total=   1.1s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.630, total=   2.0s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.824, total=   1.2s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.739, total=   1.2s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.740, total=   1.2s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.584, total=   1.1s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.747, total=   1.2s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.830, total=   1.2s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.647, total=   1.1s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.773, total=   1.1s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.734, total=   1.2s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.734, total=   1.3s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.791, total=   1.2s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.712, total=   1.2s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.649, total=   1.2s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.584, total=   1.1s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.766, total=   1.1s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.817, total=   1.1s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.758, total=   1.1s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.766, total=   1.1s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.734, total=   2.0s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.760, total=   1.3s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.817, total=   1.2s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.771, total=   1.2s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.760, total=   1.2s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.714, total=   1.2s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.675, total=   1.2s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.824, total=   1.2s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.778, total=   1.2s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.747, total=   1.1s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.669, total=   1.1s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.766, total=   1.2s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.817, total=   1.2s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.771, total=   1.1s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   54.1s finished

# %%
# Summarize the results

print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7695951104164124, using {'neuron1': 16, 'neuron2': 2}
# 0.7135727047920227,0.06144321083100852 with: {'neuron1': 4, 'neuron2': 2}
# 0.6850691795349121,0.05486673939643067 with: {'neuron1': 4, 'neuron2': 4}
# 0.7033273935317993,0.08554532108186408 with: {'neuron1': 4, 'neuron2': 8}
# 0.7097105622291565,0.08534022815335571 with: {'neuron1': 8, 'neuron2': 2}
# 0.7487055540084839,0.028692502222565846 with: {'neuron1': 8, 'neuron2': 4}
# 0.7150326728820801,0.08515085410206095 with: {'neuron1': 8, 'neuron2': 8}
# 0.7695951104164124,0.026986814450906067 with: {'neuron1': 16, 'neuron2': 2}
# 0.7501315712928772,0.051234519316745185 with: {'neuron1': 16, 'neuron2': 4}
# 0.7540107011795044,0.048417698472008594 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# # FINAL MODEL

# %%
from sklearn.metrics import classification_report, accuracy_score

# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(0.0))
    model.add(Dense(4,input_dim = 16,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(0.0))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics

print(accuracy_score(y,y_predict))
print(classification_report(y,y_predict))
# Out:
# 0.8059895833333334
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       500
#            1       0.75      0.67      0.71       268
#
#     accuracy                           0.81       768
#    macro avg       0.79      0.77      0.78       768
# weighted avg       0.80      0.81      0.80       768
